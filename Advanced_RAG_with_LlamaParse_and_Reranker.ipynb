# %%
# %%capture
# !pip install llama-index
# !pip install llama-index-core
# !pip install llama-index-embeddings-openai
# !pip install llama-index-postprocessor-flag-embedding-reranker
# !pip install git+https://github.com/FlagOpen/FlagEmbedding.git
# !pip install llama-parse
# !pip install llama-index-embeddings-fastembed
# !pip install fastembed
# !pip install llama-index-llms-groq

# %%
# !wget 'https://huggingface.co/silaseic/llamaindex_demo/resolve/main/uber_10q_march_2022.pdf?download=true' -O './uber_10q_march_2022.pdf'
# Out:
# --2024-04-02 15:27:47--  https://huggingface.co/silaseic/llamaindex_demo/resolve/main/uber_10q_march_2022.pdf?download=true
# Resolving huggingface.co (huggingface.co)... 65.8.178.12, 65.8.178.93, 65.8.178.118, ...
# Connecting to huggingface.co (huggingface.co)|65.8.178.12|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-us-1.huggingface.co/repos/db/82/db822043772ccb03c50d147d5942e00187b2c9684beaf6b475f70ff50e2e4b9f/e03fd66bebeef51aa4708a0e5506309734f4676dde85fb5f17f571c0d3f4d4bc?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27uber_10q_march_2022.pdf%3B+filename%3D%22uber_10q_march_2022.pdf%22%3B&response-content-type=application%2Fpdf&Expires=1712330867&Policy=...&Signature=dvIuUdpQkvi9L6B8vAmufpfKxosgJJ0-9hDPrrmhYxZizE7i8EVrjSeNOE5SFUa0YYc9eqKpmAHn6Qb4VxjcqQcAxB%7EFn1eqryHCZ7UOE8mLJOqVH%7EGUpBr4RLYYYxNI-FjRwkn8UBpBxQATQS3VdSNNNXZiY4%7Ez9IPRsySbuTYDMqFkXA0pQ69OS5dopo4BT%7E4YxSPnmKbbHba3vo63lZ38qMU-6l2RvAeLJIzvWyDp637wpLX7Huy3rAoFJyNtD7aMhcYQOmPI9ifeDZTIo94W6bton91rwPb-GO5Ghe6DE5WIOds18foj3Q46aFgAOzHu6EEoa0pg74qVf2OH-Q__&Key-Pair-Id=KCD77M1F0VK2B [following]
# --2024-04-02 15:27:47--  https://cdn-lfs-us-1.huggingface.co/repos/db/82/db822043772ccb03c50d147d5942e00187b2c9684beaf6b475f70ff50e2e4b9f/e03fd66bebeef51aa4708a0e5506309734f4676dde85fb5f17f571c0d3f4d4bc?response-content-disposition=attachment%3B+filename*%3DUTF-8%27%27uber_10q_march_2022.pdf%3B+filename%3D%22uber_10q_march_2022.pdf%22%3B&response-content-type=application%2Fpdf&Expires=1712330867&Policy=...&Signature=dvIuUdpQkvi9L6B8vAmufpfKxosgJJ0-9hDPrrmhYxZizE7i8EVrjSeNOE5SFUa0YYc9eqKpmAHn6Qb4VxjcqQcAxB%7EFn1eqryHCZ7UOE8mLJOqVH%7EGUpBr4RLYYYxNI-FjRwkn8UBpBxQATQS3VdSNNNXZiY4%7Ez9IPRsySbuTYDMqFkXA0pQ69OS5dopo4BT%7E4YxSPnmKbbHba3vo63lZ38qMU-6l2RvAeLJIzvWyDp637wpLX7Huy3rAoFJyNtD7aMhcYQOmPI9ifeDZTIo94W6bton91rwPb-GO5Ghe6DE5WIOds18foj3Q46aFgAOzHu6EEoa0pg74qVf2OH-Q__&Key-Pair-Id=KCD77M1F0VK2B
# Resolving cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)... 13.249.98.16, 13.249.98.99, 13.249.98.125, ...
# Connecting to cdn-lfs-us-1.huggingface.co (cdn-lfs-us-1.huggingface.co)|13.249.98.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1260185 (1.2M) [application/pdf]
# Saving to: ‘./uber_10q_march_2022.pdf’
#
# ./uber_10q_march_20 100%[===================>]   1.20M  --.-KB/s    in 0.1s
#
# 2024-04-02 15:27:47 (11.6 MB/s) - ‘./uber_10q_march_2022.pdf’ saved [1260185/1260185]

# %%
# llama-parse is async-first, running the async code in a notebook requires the use of nest_asyncio
import nest_asyncio
nest_asyncio.apply()

# API access to llama-cloud
#LLAMA_CLOUD_API_KEY = "llx-*****"

# Using OpenAI API for embeddings/llms
#GROQ_API_KEY = "gsk_*****"

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Using brand new LlamaParse PDF reader for PDF Parsing
# we also compare two different retrieval/query engine strategies:
#
# Using raw Markdown text as nodes for building index and apply simple query engine for generating the results;
# Using MarkdownElementNodeParser for parsing the LlamaParse output Markdown results and building recursive retriever query engine for generation.

# %%
from llama_parse import LlamaParse
from google.colab import userdata
LLAMA_CLOUD_API_KEY = userdata.get('llama_cloud_key')

import pickle
import os
# Define a function to load parsed data if available, or parse if not
def load_or_parse_data():
    data_file = "./parsed_data.pkl"

    if os.path.exists(data_file):
        # Load the parsed data from the file
        with open(data_file, "rb") as f:
            parsed_data = pickle.load(f)
    else:
        # Perform the parsing step and store the result in llama_parse_documents
        parsingInstructionUber10k = """The provided document is a quarterly report filed by Uber Technologies,
        Inc. with the Securities and Exchange Commission (SEC).
        This form provides detailed financial information about the company's performance for a specific quarter.
        It includes unaudited financial statements, management discussion and analysis, and other relevant disclosures required by the SEC.
        It contains many tables.
        Try to be precise while answering the questions"""
        parser = LlamaParse(api_key=LLAMA_CLOUD_API_KEY, result_type="markdown", parsing_instruction=parsingInstructionUber10k)
        llama_parse_documents = parser.load_data("/content/uber_10q_march_2022.pdf")


        # Save the parsed data to a file
        with open(data_file, "wb") as f:
            pickle.dump(llama_parse_documents, f)

        # Set the parsed data to the variable
        parsed_data = llama_parse_documents

    return parsed_data

documents =  load_or_parse_data()

#documents = LlamaParse(api_key=LLAMA_CLOUD_API_KEY, result_type="markdown").load_data('./uber_10q_march_2022.pdf')
# Out:
# Started parsing the file under job_id bb7db381-7993-4b68-847b-3d4414d1630b

# %%
print(documents[0].text[:1000] + '...')
# Out:
# # Uber Technologies, Inc. - Quarterly Report
#
# # Uber Technologies, Inc. - Quarterly Report
#
# Form 10-Q
#
# Quarterly Report Pursuant to Section 13 or 15(d) of the Securities Exchange Act of 1934
#
# For the quarterly period ended March 31, 2022
#
# Commission File Number: 001-38902
#
# Uber Technologies, Inc.
#
# Address: 1515 3rd Street, San Francisco, California 94158
#
# Telephone: (415) 612-8582
#
# ## Securities Registered
#
# |Title of each class|Trading Symbol(s)|Name of each exchange on which registered|
# |---|---|---|
# |Common Stock, par value $0.00001 per share|UBER|New York Stock Exchange|
#
# ## Filing Information
#
# Filed all reports required in the past 12 months: Yes
#
# Submitted Interactive Data File: Yes
#
# Large accelerated filer: Yes
#
# Accelerated filer: No
#
# Non-accelerated filer: No
#
# Smaller reporting company: No
#
# Emerging growth company: No
#
# ## Additional Information
#
# Shell company: No
#
# Number of shares outstanding (as of May 2, 2022): 1,963,660,253
# ---
# # Uber Technologies, Inc. Quarterly Report
#
# # UB...

# %%
from llama_index.core import VectorStoreIndex
from llama_index.llms.groq import Groq
from llama_index.embeddings.fastembed import FastEmbedEmbedding
from llama_index.core import Settings
GROQ_API_KEY = userdata.get('groq_cloud_key')

# by default llamaindex uses OpenAI models
embed_model = FastEmbedEmbedding(model_name="BAAI/bge-base-en-v1.5")

llm = Groq(model="mixtral-8x7b-32768", api_key= GROQ_API_KEY)

Settings.llm = llm
Settings.embed_model = embed_model
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 8 files:   0%|          | 0/8 [00:00<?, ?it/s]
# config.json:   0%|          | 0.00/740 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# ort_config.json:   0%|          | 0.00/1.27k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.24k [00:00<?, ?B/s]
# model_optimized.onnx:   0%|          | 0.00/218M [00:00<?, ?B/s]

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

node_parser = MarkdownElementNodeParser(llm = Groq(model="mixtral-8x7b-32768", api_key= GROQ_API_KEY), num_workers=8)

# %%
nodes = node_parser.get_nodes_from_documents(documents)
# Out:
# 56it [00:00, 12893.51it/s]
#   0%|          | 0/56 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/llama_index/core/program/utils.py:58: UserWarning: Failed to use `OpenAIPydanticProgram`. Please ensure that is installed by running `pip install llama-index-program-openai`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/llama_index/core/program/utils.py:58: UserWarning: Failed to use `OpenAIPydanticProgram`. Please ensure that is installed by running `pip install llama-index-program-openai`.
#   warnings.warn(
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#   5%|▌         | 3/56 [00:06<01:32,  1.74s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#   7%|▋         | 4/56 [00:12<02:51,  3.29s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  14%|█▍        | 8/56 [00:15<01:03,  1.33s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  18%|█▊        | 10/56 [00:17<00:51,  1.13s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  20%|█▉        | 11/56 [00:21<01:19,  1.77s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  21%|██▏       | 12/56 [00:23<01:16,  1.73s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  25%|██▌       | 14/56 [00:25<00:56,  1.34s/it]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py", line 130, in acall
#     output = self._output_parser.parse(raw_output)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py", line 62, in parse
#     return self._output_cls.parse_raw(json_str)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#  27%|██▋       | 15/56 [00:27<01:09,  1.70s/it]WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.3827073566432997 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `mixtral-8x7b-32768` in organization `org_01htfqgnqqf9tvftrnkzygnrz0` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.456s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.9214622500275703 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `mixtral-8x7b-32768` in organization `org_01htfqgnqqf9tvftrnkzygnrz0` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.369s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.2238822766989118 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `mixtral-8x7b-32768` in organization `org_01htfqgnqqf9tvftrnkzygnrz0` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.843s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# WARNING:llama_index.llms.openai.utils:Retrying llama_index.llms.openai.base.OpenAI._achat in 0.07528675070705049 seconds as it raised RateLimitError: Error code: 429 - {'error': {'message': 'Rate limit reached for model `mixtral-8x7b-32768` in organization `org_01htfqgnqqf9tvftrnkzygnrz0` on requests per minute (RPM): Limit 30, Used 30, Requested 1. Please try again in 1.508s. Visit https://console.groq.com/docs/rate-limits for more information.', 'type': 'requests', 'code': 'rate_limit_exceeded'}}.
# ...
#     171             try:
# --> 172                 response = await query_engine.aquery(summary_query_str)
#     173                 return cast(PydanticResponse, response).response
#     174             except ValidationError:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/base/base_query_engine.py in aquery(self, str_or_query_bundle)
#      59             if isinstance(str_or_query_bundle, str):
#      60                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 61             query_result = await self._aquery(str_or_query_bundle)
#      62         dispatcher.event(QueryEndEvent())
#      63         return query_result
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in _aquery(self, query_bundle)
#     204             nodes = await self.aretrieve(query_bundle)
#     205
# --> 206             response = await self._response_synthesizer.asynthesize(
#     207                 query=query_bundle,
#     208                 nodes=nodes,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/base.py in asynthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     275             CBEventType.SYNTHESIZE, payload={EventPayload.QUERY_STR: query.query_str}
#     276         ) as event:
# --> 277             response_str = await self.aget_response(
#     278                 query_str=query.query_str,
#     279                 text_chunks=[
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/compact_and_refine.py in aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      21     ) -> RESPONSE_TEXT_TYPE:
#      22         compact_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 23         return await super().aget_response(
#      24             query_str=query_str,
#      25             text_chunks=compact_texts,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in aget_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     357                 # if this is the first chunk, and text chunk already
#     358                 # is an answer, then return it
# --> 359                 response = await self._agive_response_single(
#     360                     query_str, text_chunk, **response_kwargs
#     361                 )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in _agive_response_single(self, query_str, text_chunk, **response_kwargs)
#     475             if response is None and not self._streaming:
#     476                 try:
# --> 477                     structured_response = await program.acall(
#     478                         context_str=cur_text_chunk,
#     479                         **response_kwargs,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py in acall(self, *args, **kwds)
#      90     async def acall(self, *args: Any, **kwds: Any) -> StructuredRefineResponse:
#      91         if self._output_cls is not None:
# ---> 92             answer = await self._llm.astructured_predict(
#      93                 self._output_cls,
#      94                 self._prompt,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
# --> 162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#     163                 raise
#     164             else:
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      96         while c:
#      97             for h in c.span_handlers:
# ---> 98                 h.span_drop(
#      99                     *args,
#     100                     id_=id_,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py in span_drop(self, id_, bound_args, instance, err, *args, **kwargs)
#      75     ) -> None:
#      76         """Logic for dropping a span i.e. early exit."""
# ---> 77         span = self.prepare_to_drop_span(
#      78             id_=id_, bound_args=bound_args, instance=instance, err=err
#      79         )
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py in prepare_to_drop_span(self, id_, bound_args, instance, err, *args, **kwargs)
#      69         """Logic for droppping a span."""
#      70         if err:
# ---> 71             raise err
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py in async_wrapper(func, instance, args, kwargs)
#     158             self.span_enter(id_=id_, bound_args=bound_args, instance=instance)
#     159             try:
# --> 160                 result = await func(*args, **kwargs)
#     161             except BaseException as e:
#     162                 self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py in astructured_predict(self, output_cls, prompt, **prompt_args)
#     377         )
#     378
# --> 379         return await program.acall(**prompt_args)
#     380
#     381     # -- Prompt Chaining --
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/program/llm_program.py in acall(self, llm_kwargs, *args, **kwargs)
#     128             raw_output = response.text
#     129
# --> 130         output = self._output_parser.parse(raw_output)
#     131         if not isinstance(output, self._output_cls):
#     132             raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/pydantic.py in parse(self, text)
#      59     def parse(self, text: str) -> Any:
#      60         """Parse, validate, and correct errors programmatically."""
# ---> 61         json_str = extract_json_str(text)
#      62         return self._output_cls.parse_raw(json_str)
#      63
#
# /usr/local/lib/python3.10/dist-packages/llama_index/core/output_parsers/utils.py in extract_json_str(text)
#     110     match = re.search(r"\{.*\}", text.strip(), re.MULTILINE | re.IGNORECASE | re.DOTALL)
#     111     if not match:
# --> 112         raise ValueError(f"Could not extract json string from output: {text}")
#     113
#     114     return match.group()
#
# ValueError: Could not extract json string from output: {"summary": "This table provides a breakdown of the balance sheet for three segments of a company, including balances as of December 31, 2021, acquisitions, and balances as of March 31, 2

# %% [markdown]
# Tried Groq's model but timeout issue, json string extraction problem persists, switched to OpenAI model.

# %%
from llama_index.core.node_parser import MarkdownElementNodeParser

from llama_index.llms.openai import OpenAI
from llama_index.embeddings.openai import OpenAIEmbedding
from llama_index.core import VectorStoreIndex
from llama_index.core import Settings
OPENAI_API_KEY = userdata.get('api_key')


embed_model=OpenAIEmbedding(model="text-embedding-3-small", api_key=OPENAI_API_KEY)
llm = OpenAI(model="gpt-3.5-turbo-0125", api_key=OPENAI_API_KEY)

Settings.embed_model = embed_model
Settings.llm = llm

node_parser = MarkdownElementNodeParser(llm = llm, num_workers=8)

# %%
nodes = node_parser.get_nodes_from_documents(documents, progress =True)
# Out:
# 56it [00:00, 11841.75it/s]
#
#   0%|          | 0/56 [00:00<?, ?it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#   2%|▏         | 1/56 [00:01<01:25,  1.55s/it]
#   4%|▎         | 2/56 [00:01<00:46,  1.17it/s]
#   5%|▌         | 3/56 [00:02<00:32,  1.65it/s]
#   9%|▉         | 5/56 [00:02<00:17,  2.89it/s]
#  11%|█         | 6/56 [00:03<00:21,  2.33it/s]
#  12%|█▎        | 7/56 [00:03<00:17,  2.81it/s]
#  14%|█▍        | 8/56 [00:03<00:20,  2.33it/s]
#  16%|█▌        | 9/56 [00:04<00:16,  2.84it/s]
#  18%|█▊        | 10/56 [00:04<00:14,  3.13it/s]
#  20%|█▉        | 11/56 [00:04<00:12,  3.74it/s]
#  21%|██▏       | 12/56 [00:04<00:09,  4.47it/s]
#  23%|██▎       | 13/56 [00:05<00:13,  3.25it/s]
#  25%|██▌       | 14/56 [00:05<00:10,  3.87it/s]
#  29%|██▊       | 16/56 [00:05<00:09,  4.33it/s]
#  30%|███       | 17/56 [00:05<00:08,  4.82it/s]
#  32%|███▏      | 18/56 [00:06<00:09,  3.96it/s]
#  34%|███▍      | 19/56 [00:06<00:11,  3.28it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  36%|███▌      | 20/56 [00:07<00:14,  2.56it/s]
#  38%|███▊      | 21/56 [00:07<00:11,  2.96it/s]
#  39%|███▉      | 22/56 [00:07<00:09,  3.61it/s]
#  41%|████      | 23/56 [00:07<00:07,  4.14it/s]
#  43%|████▎     | 24/56 [00:07<00:06,  4.92it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  46%|████▋     | 26/56 [00:08<00:04,  6.15it/s]
#  48%|████▊     | 27/56 [00:08<00:09,  3.08it/s]
#  50%|█████     | 28/56 [00:09<00:10,  2.67it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  52%|█████▏    | 29/56 [00:09<00:08,  3.26it/s]
#  54%|█████▎    | 30/56 [00:09<00:08,  2.97it/s]
#  57%|█████▋    | 32/56 [00:10<00:05,  4.68it/s]
#  59%|█████▉    | 33/56 [00:10<00:04,  4.78it/s]
#  62%|██████▎   | 35/56 [00:10<00:03,  6.02it/s]
#  64%|██████▍   | 36/56 [00:10<00:03,  6.34it/s]
#  66%|██████▌   | 37/56 [00:11<00:06,  2.85it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  68%|██████▊   | 38/56 [00:11<00:05,  3.03it/s]
#  70%|██████▉   | 39/56 [00:12<00:06,  2.75it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  73%|███████▎  | 41/56 [00:12<00:03,  4.07it/s]
#  75%|███████▌  | 42/56 [00:13<00:05,  2.50it/s]
#  77%|███████▋  | 43/56 [00:13<00:04,  3.05it/s]
#  79%|███████▊  | 44/56 [00:13<00:03,  3.67it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  82%|████████▏ | 46/56 [00:14<00:02,  4.04it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  84%|████████▍ | 47/56 [00:14<00:02,  3.07it/s]
#  86%|████████▌ | 48/56 [00:15<00:02,  2.78it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  88%|████████▊ | 49/56 [00:15<00:02,  2.98it/s]
#  89%|████████▉ | 50/56 [00:15<00:01,  3.47it/s]
#  91%|█████████ | 51/56 [00:16<00:01,  2.68it/s]WARNING:llama_index.core.response_synthesizers.refine:Validation error on structured response: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 477, in _agive_response_single
#     structured_response = await program.acall(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/response_synthesizers/refine.py", line 92, in acall
#     answer = await self._llm.astructured_predict(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 162, in async_wrapper
#     self.span_drop(id_=id_, bound_args=bound_args, instance=instance, err=e)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 98, in span_drop
#     h.span_drop(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/base.py", line 77, in span_drop
#     span = self.prepare_to_drop_span(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/span_handlers/null.py", line 71, in prepare_to_drop_span
#     raise err
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/instrumentation/dispatcher.py", line 160, in async_wrapper
#     result = await func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/core/llms/llm.py", line 379, in astructured_predict
#     return await program.acall(**prompt_args)
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 220, in acall
#     return _parse_tool_calls(
#   File "/usr/local/lib/python3.10/dist-packages/llama_index/program/openai/base.py", line 64, in _parse_tool_calls
#     output = output_cls.parse_raw(function_call.arguments)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 549, in parse_raw
#     return cls.parse_obj(obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 526, in parse_obj
#     return cls(**obj)
#   File "/usr/local/lib/python3.10/dist-packages/pydantic/v1/main.py", line 341, in __init__
#     raise validation_error
# pydantic.v1.error_wrappers.ValidationError: 1 validation error for TableOutput
# columns
#   field required (type=value_error.missing)
#
#  95%|█████████▍| 53/56 [00:16<00:01,  2.98it/s]
#  96%|█████████▋| 54/56 [00:17<00:00,  2.85it/s]
#  98%|█████████▊| 55/56 [00:17<00:00,  3.31it/s]
# 100%|██████████| 56/56 [00:18<00:00,  2.96it/s]

# %%
llm
# Out:
# OpenAI(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x7953ff66b3d0>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x795407fb3370>, completion_to_prompt=<function default_completion_to_prompt at 0x795407e4d7e0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='gpt-3.5-turbo-0125', temperature=0.1, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.openai.com/v1', api_version='')

# %%
base_nodes, objects = node_parser.get_nodes_and_objects(nodes)

# %%
recursive_index = VectorStoreIndex(nodes=base_nodes+objects)
raw_index = VectorStoreIndex.from_documents(documents)

# %%
from llama_index.postprocessor.flag_embedding_reranker import FlagEmbeddingReranker

reranker = FlagEmbeddingReranker(
    top_n=5,
    model="BAAI/bge-reranker-large",
)

recursive_query_engine = recursive_index.as_query_engine(
    similarity_top_k=15,
    node_postprocessors=[reranker],
    verbose=True
)

raw_query_engine = raw_index.as_query_engine(similarity_top_k=15, node_postprocessors=[reranker])
# Out:
# tokenizer_config.json:   0%|          | 0.00/443 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/279 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/801 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]

# %%
print(len(nodes))
# Out:
# 221

# %% [markdown]
# Using new LlamaParse as pdf data parsing methods and retrieve tables with two different methods
# we compare base query engine vs recursive query engine with tables
#
# Table Query Task: Queries for Table Question Answering

# %%
query = "how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# Cash paid for income taxes, net of refunds, is $22 million based on the Supplemental disclosures of cash flow information.
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_98_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_94_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_84_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_96_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_82_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_546_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_178_table: TextNode
# Retrieving from object TextNode with query how is the Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The Cash paid for Income taxes, net of refunds from Supplemental disclosures of cash flow information can be calculated by subtracting any refunds received from the total amount of cash paid for income taxes.

# %%
query = "what is the change of free cash flow and what is the rate from the financial and operational highlights?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The change in free cash flow from the financial and operational highlights is an increase of $228 million. The rate of this change is not provided in the context information.
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_546_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_84_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_98_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_82_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_430_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_86_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_482_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_540_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_356_table: TextNode
# Retrieving from object TextNode with query what is the change of free cash flow and what is the rate from the financial and operational highlights?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The change in free cash flow from the financial and operational highlights is an improvement of $635 million, with the rate being a positive $635 million.

# %%
query = "what is the net loss value attributable to Uber compared to last year?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# The net loss attributable to Uber Technologies, Inc. this year was $5.9 billion, whereas last year it was $122 million.
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_372_table: TextNode
# Retrieving from object TextNode with query what is the net loss value attributable to Uber compared to last year?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# The net loss value attributable to Uber Technologies, Inc. for the current year is $5,930 million, which is significantly higher compared to the net loss of $108 million for the same period last year.

# %%
query = "What were cash flows like from investing activities?"

response_1 = raw_query_engine.query(query)
print("\n***********New LlamaParse+ Basic Query Engine***********")
print(response_1)

response_2 = recursive_query_engine.query(query)
print("\n***********New LlamaParse+ Recursive Retriever Query Engine***********")
print(response_2)
# Out:
# ***********New LlamaParse+ Basic Query Engine***********
# Cash flows from investing activities were a net outflow of $135 million for the three months ended March 31, 2022. This primarily consisted of $62 million in purchases of property and equipment and $59 million in the acquisition of businesses, net of cash acquired.
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_84_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_98_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_546_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_86_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_94_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_470_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
# Retrieval entering id_ddb6a698-3081-4b24-afcc-64f00a29795d_82_table: TextNode
# Retrieving from object TextNode with query What were cash flows like from investing activities?
#
# ***********New LlamaParse+ Recursive Retriever Query Engine***********
# Cash flows from investing activities were $250 million for the three months ended March 31, 2021, and $135 million for the three months ended March 31, 2022.

# %% [markdown]
# https://www.youtube.com/watch?v=wCFXae8hiYA

# %% [markdown]
# Sudarshan Koirala
